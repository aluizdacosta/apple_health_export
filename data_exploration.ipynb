# %%
import xml.etree.ElementTree as ET
import pandas as pd

# %%
tree = ET.parse('export.xml')
root = tree.getroot()

# %%
print(root)
# Out:
# <Element 'HealthData' at 0x1081e2c00>

# %%
df = pd.read_xml('export.xml', xpath='.//Record')

# %%
df
# Out:
#                                                      type  \
# 0                   HKQuantityTypeIdentifierBodyMassIndex
# 1                   HKQuantityTypeIdentifierBodyMassIndex
# 2                   HKQuantityTypeIdentifierBodyMassIndex
# 3                   HKQuantityTypeIdentifierBodyMassIndex
# 4                   HKQuantityTypeIdentifierBodyMassIndex
# ...                                                   ...
# 5032664  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 5032665  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 5032666  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 5032667  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 5032668  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
#
#                   sourceName sourceVersion   unit               creationDate  \
# 0                  Zepp Life  202205261736  count  2022-06-04 11:42:20 -0300
# 1                  Zepp Life  202207011713  count  2022-07-09 11:49:24 -0300
# 2                  Zepp Life  202207011713  count  2022-07-16 11:28:09 -0300
# 3                  Zepp Life  202207011713  count  2022-08-13 11:39:05 -0300
# 4                  Zepp Life  202207011713  count  2022-08-13 11:53:02 -0300
# ...                      ...           ...    ...                        ...
# 5032664  Andre’s Apple Watch        11.3.1     ms  2025-02-28 21:47:25 -0300
# 5032665  Andre’s Apple Watch        11.3.1     ms  2025-02-28 23:47:25 -0300
# 5032666  Andre’s Apple Watch        11.3.1     ms  2025-03-01 01:47:28 -0300
# 5032667  Andre’s Apple Watch        11.3.1     ms  2025-03-01 03:47:28 -0300
# 5032668  Andre’s Apple Watch        11.3.1     ms  2025-03-01 05:47:24 -0300
#
#                          startDate                    endDate    value  \
# 0        2022-06-04 11:42:15 -0300  2022-06-04 11:42:15 -0300       23
# 1        2022-07-09 11:49:18 -0300  2022-07-09 11:49:18 -0300     23.1
# 2        2022-07-16 11:28:04 -0300  2022-07-16 11:28:04 -0300     23.4
# 3        2022-08-02 10:31:49 -0300  2022-08-02 10:31:49 -0300  23.7253
# 4        2022-08-13 11:52:56 -0300  2022-08-13 11:52:56 -0300     23.3
# ...                            ...                        ...      ...
# 5032664  2025-02-28 21:46:24 -0300  2025-02-28 21:47:23 -0300  40.6716
# 5032665  2025-02-28 23:46:24 -0300  2025-02-28 23:47:24 -0300  67.4447
# 5032666  2025-03-01 01:46:27 -0300  2025-03-01 01:47:26 -0300  174.078
# 5032667  2025-03-01 03:46:27 -0300  2025-03-01 03:47:26 -0300  136.275
# 5032668  2025-03-01 05:46:23 -0300  2025-03-01 05:47:23 -0300  49.4455
#
#                                                     device  MetadataEntry  \
# 0                                                     None            NaN
# 1                                                     None            NaN
# 2                                                     None            NaN
# 3                                                     None            NaN
# 4                                                     None            NaN
# ...                                                    ...            ...
# 5032664  <<HKDevice: 0x30091e350>, name:Apple Watch, ma...            NaN
# 5032665  <<HKDevice: 0x30091e350>, name:Apple Watch, ma...            NaN
# 5032666  <<HKDevice: 0x30091e350>, name:Apple Watch, ma...            NaN
# 5032667  <<HKDevice: 0x30091e350>, name:Apple Watch, ma...            NaN
# 5032668  <<HKDevice: 0x30091e350>, name:Apple Watch, ma...            NaN
#
#         HeartRateVariabilityMetadataList
# 0                                   None
# 1                                   None
# 2                                   None
# 3                                   None
# 4                                   None
# ...                                  ...
# 5032664                            \n
# 5032665                            \n
# 5032666                            \n
# 5032667                            \n
# 5032668                            \n
#
# [5032669 rows x 11 columns]

# %%
df.groupby("type").count()
# Out:
#                                                     sourceName  sourceVersion  \
# type
# HKCategoryTypeIdentifierAppleStandHour                   49348          49348
# HKCategoryTypeIdentifierAudioExposureEvent                 232            232
# HKCategoryTypeIdentifierHeadphoneAudioExposureE...           1              1
# HKCategoryTypeIdentifierMindfulSession                     587            587
# HKCategoryTypeIdentifierSleepAnalysis                    46380          46380
# ...                                                        ...            ...
# HKQuantityTypeIdentifierWalkingAsymmetryPercentage        8753           8753
# HKQuantityTypeIdentifierWalkingDoubleSupportPer...       17402          17402
# HKQuantityTypeIdentifierWalkingHeartRateAverage           2020           2020
# HKQuantityTypeIdentifierWalkingSpeed                     21062          21062
# HKQuantityTypeIdentifierWalkingStepLength                21060          21060
#
#                                                      unit  creationDate  \
# type
# HKCategoryTypeIdentifierAppleStandHour                  0         49348
# HKCategoryTypeIdentifierAudioExposureEvent              0           232
# HKCategoryTypeIdentifierHeadphoneAudioExposureE...      0             1
# HKCategoryTypeIdentifierMindfulSession                  0           587
# HKCategoryTypeIdentifierSleepAnalysis                   0         46380
# ...                                                   ...           ...
# HKQuantityTypeIdentifierWalkingAsymmetryPercentage   8753          8753
# HKQuantityTypeIdentifierWalkingDoubleSupportPer...  17402         17402
# HKQuantityTypeIdentifierWalkingHeartRateAverage      2020          2020
# HKQuantityTypeIdentifierWalkingSpeed                21062         21062
# HKQuantityTypeIdentifierWalkingStepLength           21060         21060
#
#                                                     startDate  endDate  value  \
# type
# HKCategoryTypeIdentifierAppleStandHour                  49348    49348  49348
# HKCategoryTypeIdentifierAudioExposureEvent                232      232    232
# HKCategoryTypeIdentifierHeadphoneAudioExposureE...          1        1      1
# HKCategoryTypeIdentifierMindfulSession                    587      587    587
# HKCategoryTypeIdentifierSleepAnalysis                   46380    46380  46380
# ...                                                       ...      ...    ...
# HKQuantityTypeIdentifierWalkingAsymmetryPercentage       8753     8753   8753
# HKQuantityTypeIdentifierWalkingDoubleSupportPer...      17402    17402  17402
# HKQuantityTypeIdentifierWalkingHeartRateAverage          2020     2020   2020
# HKQuantityTypeIdentifierWalkingSpeed                    21062    21062  21062
# HKQuantityTypeIdentifierWalkingStepLength               21060    21060  21060
#
#                                                     device  MetadataEntry  \
# type
# HKCategoryTypeIdentifierAppleStandHour               49217              0
# HKCategoryTypeIdentifierAudioExposureEvent             232              0
# HKCategoryTypeIdentifierHeadphoneAudioExposureE...       0              0
# HKCategoryTypeIdentifierMindfulSession                   0              0
# HKCategoryTypeIdentifierSleepAnalysis                   16              0
# ...                                                    ...            ...
# HKQuantityTypeIdentifierWalkingAsymmetryPercentage    8753              0
# HKQuantityTypeIdentifierWalkingDoubleSupportPer...   17402              0
# HKQuantityTypeIdentifierWalkingHeartRateAverage          0              0
# HKQuantityTypeIdentifierWalkingSpeed                 21062              0
# HKQuantityTypeIdentifierWalkingStepLength            21060              0
#
#                                                     HeartRateVariabilityMetadataList
# type
# HKCategoryTypeIdentifierAppleStandHour                                             0
# HKCategoryTypeIdentifierAudioExposureEvent                                         0
# HKCategoryTypeIdentifierHeadphoneAudioExposureE...                                 0
# HKCategoryTypeIdentifierMindfulSession                                             0
# HKCategoryTypeIdentifierSleepAnalysis                                              0
# ...                                                                              ...
# HKQuantityTypeIdentifierWalkingAsymmetryPercentage                                 0
# HKQuantityTypeIdentifierWalkingDoubleSupportPer...                                 0
# HKQuantityTypeIdentifierWalkingHeartRateAverage                                    0
# HKQuantityTypeIdentifierWalkingSpeed                                               0
# HKQuantityTypeIdentifierWalkingStepLength                                          0
#
# [62 rows x 10 columns]

# %%
df.groupby("sourceName").count()
# Out:
#                         type  sourceVersion     unit  creationDate  startDate  \
# sourceName
# 7 Minutes                157            157      157           157        157
# Andre’s Apple Watch  4633318        4620156  4541470       4633318    4633318
# Andre’s iPhone           977            977      977           977        977
# Bluetooth Device      127663         127663   127663        127663     127663
# Clock                     16             16        0            16         16
# Forest                    44             44        0            44         44
# Health                     4              4        4             4          4
# InBody                   260            260      260           260        260
# MyFitnessPal            2968           2968     2968          2968       2968
# Sleep Cycle             1528           1528      302          1528       1528
# Strava                    85             85       85            85         85
# WHM                       34             34        0            34         34
# Waking Up                507            507        0           507        507
# Zepp Life               3374           3374     3374          3374       3374
# iPhone                     5              5        5             5          5
# iPhone de André       261729         261729   258856        261729     261729
#
#                      endDate    value   device  MetadataEntry  \
# sourceName
# 7 Minutes                157      157        0              0
# Andre’s Apple Watch  4633318  4633318  4255041              0
# Andre’s iPhone           977      977      977              0
# Bluetooth Device      127663   127663   127663              0
# Clock                     16       16       16              0
# Forest                    44       44        0              0
# Health                     4        4        0              0
# InBody                   260      260        0              0
# MyFitnessPal            2968     2968        0              0
# Sleep Cycle             1528     1528        0              0
# Strava                    85       85        0              0
# WHM                       34       34        0              0
# Waking Up                507      507        0              0
# Zepp Life               3374     3374        0              0
# iPhone                     5        5        5              0
# iPhone de André       261729   261729   256488              0
#
#                      HeartRateVariabilityMetadataList
# sourceName
# 7 Minutes                                           0
# Andre’s Apple Watch                             13562
# Andre’s iPhone                                      0
# Bluetooth Device                                    0
# Clock                                               0
# Forest                                              0
# Health                                              0
# InBody                                              0
# MyFitnessPal                                        0
# Sleep Cycle                                         0
# Strava                                              0
# WHM                                                 0
# Waking Up                                           0
# Zepp Life                                           0
# iPhone                                              0
# iPhone de André                                     0

# %%
df.groupby("type").count().to_excel("types.xlsx")

# %%
df[df["sourceName"] == "InBody"].to_excel("inbody_excel.xlsx")
